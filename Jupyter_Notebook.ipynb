# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My first Jupyter Notebook

# %% [markdown]
# <b>Introduction Cell</b>
#
# <div style="padding-left: 30px;">
# I'm creating this code in order to complete the components required for this assignment. I don't have a lot to add substantively, just that I'm pretty tired right now.

# %% [markdown]
# <b>Data Science Languages</b>
#
# <div style="padding-left: 30px;">
# <ul>
# <li>LaTeX</li>
# <li>R</li>
# <li>Python</li>
# <li>Apache MLlib</li>
# <li>C++</li>
# </ul>

# %% [markdown]
# <b>Data Science Libraries</b>
#
# <div style="padding-left: 30px;">
# <ul>
# <li>ggplot2</li>
# <li>Lattice</li>
# <li>NumPy</li>
# <li>Pandas</li>
# <li>TensorFlow</li>
# </ul>

# %% [markdown]
# <b>Data Science Tools</b>
#
# <div style="padding-left: 30px;">
#   <table>
#   <tr>
#     <th>Tool</th>
#     <th>Associated Language</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>RStudio</td>
#     <td>R (and RMarkdown)</td>
#     <td>Unifies programming, execution, debugging, remote data
# access, data exploration, and visualization into one
# tool</td>
#   </tr>
#   <tr>
#     <td>Spyder</td>
#     <td>Python and others</td>
#     <td>Integrates code, documentation, and visualizations,
# among others, into a single canvas</td>
#   </tr>
#
#    <tr>
#     <td>Watson Studio</td>
#     <td>IBM cloud</td>
#     <td>A fully integrated development environment for data
# scientists</td>
#   </tr>
#   </table>
# </ul>

# %% [markdown]
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X*{j}\hat{\beta}*{j} $

# %%
# Multiplication operation
2.5*3.5
# Out:
# Running cells with 'Python 3.12.7' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Addition
2.5+3.5
# Out:
# Running cells with 'Python 3.12.7' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# <b> objectives</b>
#
# <ul>
# <li>Complete IBM Data Analyst Certificate</li>
# <li>Acquire job in data analysis</li>
# <li>Make the haters wish they hadn't been haters</li>
# </ul>

# %% [markdown]
# <b>Andy S</b>
